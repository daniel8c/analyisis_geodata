# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
os.chdir(r'C:\aa_sem_i\ZMOWO\temat_2')

# %%
x,y,z = np.loadtxt('temat_2.txt', skiprows = 1, usecols = [1,2,3], unpack = True)

# %%
# %matplotlib notebook
fig = plt.figure(figsize = (7,7))
ax = fig.add_subplot(projection = '3d')

ax.set_xlabel('Y', fontweight = 'bold')
ax.set_ylabel('X', fontweight = 'bold')
ax.set_zlabel('dz', fontweight = 'bold')

ax.set_title('Wizualizacja surowych danych')
ax.scatter(y,x,z, c = 'r')
plt.savefig('wizualizacja_surowych_danych.jpg')
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
#dz = a1*x + a2*y
A = np.c_[np.ones(x.shape),x,y]
L = z
r_x, r, rank, s = np.linalg.lstsq(A,L, rcond = 25)
s
# Out:
# array([429.65158581, 182.75654411,   2.28918998])

# %%
a0, a1, a2 = r_x
fig = plt.figure(figsize = (7,7))
ax = fig.add_subplot(projection = '3d')

ax.set_xlabel('Y', fontweight = 'bold')
ax.set_ylabel('X', fontweight = 'bold')
ax.set_zlabel('dz', fontweight = 'bold')

ax.set_title('Model 1')
ax.scatter(y,x,z, c = 'r')

#x_m = np.linspace(0,100,100)
#y_m = np.linspace(0,100,100)
#z_m = a1*x_m+a2*y_m+a0
#x_m, y_m = np.meshgrid(x_m, y_m)
#z_m = np.outer(np.ones(np.size(z_m)), z_m)
#print(z_m)
#ax.plot_surface(x_m, y_m, z_m)
#plt.savefig('wizualizacja_surowych_danych.jpg')
# Out:
# <img src="data:image/png;base64,..." width="700">
